# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import os
import jax
import jax.numpy as jnp
import visualization
from utils import results, experiments, equioutput, evaluation
import global_settings

from numpyro import distributions
import matplotlib.pyplot as plt
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
result_n1 = results.ResultSample.load_from_file(os.path.join(global_settings.PATH_PAPER_RESULTS, "{}.tar.gz".format(
    "d172bb3351d21af3d07c84b34f188223" # old pakdd results (f2 model)
    #"fa90503af1a24ee9d928da043d87e94e" # 10 samples / chain (f2 model)
    #"4e9bb1a58a0a3d093b4565507c947405" # 10 samples / chain (f1 model)
)))
result_n10 = results.ResultSample.load_from_file(os.path.join(global_settings.PATH_PAPER_RESULTS, "{}.tar.gz".format(
    #"d172bb3351d21af3d07c84b34f188223" # old pakdd results (f2 model)
    "fa90503af1a24ee9d928da043d87e94e" # 10 samples / chain (f2 model)
    #"4e9bb1a58a0a3d093b4565507c947405" # 10 samples / chain (f1 model)
)))


experiment_n1 = experiments.FactoryExperiment(result_n1.experiment_type, **{"settings": result_n1.settings})()
experiment_n10 = experiments.FactoryExperiment(result_n10.experiment_type, **{"settings": result_n10.settings})()
print(experiment_n1._settings)
print(experiment_n10._settings)
# Out:
# SettingsExperimentSample(output_path='/home/user/gw/data/experiments/paper/results', dataset='izmailov', dataset_normalization='standardization', hidden_layers=3, hidden_neurons=16, activation='tanh', activation_last_layer='none', pool_size=32, num_warmup=1024, statistic='reduced', statistic_p=0.99, identifiable_modes=3, samples_per_chain=1, seed=0, overwrite_chains=None)
# SettingsExperimentSample(output_path='/u/halle/wiese/home_at/data/experiments/paper/results', dataset='izmailov', dataset_normalization='standardization', hidden_layers=3, hidden_neurons=16, activation='tanh', activation_last_layer='none', pool_size=12, num_warmup=1024, statistic='reduced', statistic_p=0.99, identifiable_modes=3, samples_per_chain=10, seed=0, overwrite_chains=None)

# %%
def kl_divergence_old(p_values, q_values):
    assert p_values.shape == q_values.shape
    
    # normalize
    p_values /= p_values.sum()
    q_values /= q_values.sum()
    
    n = len(p_values.flatten())
    return (p_values * (jnp.log(p_values + 1e-9) - jnp.log(q_values + 1e-9))).sum()# / n

def kl_divergence(p_values, q_values):
    assert p_values.shape == q_values.shape
    
    # normalize
    p_values /= p_values.sum(1)[:, jnp.newaxis]
    q_values /= q_values.sum(1)[:, jnp.newaxis]
    
    return (p_values * (jnp.log(p_values + 1e-6) - jnp.log(q_values + 1e-6))).sum(-1)

# %%
def kl_divergence_grid(resolution, experiment, result):
    # distribution stuff
    resolution = 128 # 512
    x = jnp.linspace(-3.0, 3.0, resolution)[:, jnp.newaxis]
    y = jnp.linspace(-3.0, 3.0, resolution)[:, jnp.newaxis] # TODO why did i use 2 * resolution here before??

    #jax.scipy.special.logsumexp
    #parameters_prior_distribution = experiment._model._parameters_prior(jnp.zeros(sample.shape), jnp.ones(sample.shape))
    #std = result.samples['std'].mean()

    posterior_predictive_history = []
    posterior_predictive = jnp.zeros((x.shape[0], y.shape[0]))
    means_history = []
    kl_divergences = []
    kl_divergences_parameters = []

    n = len(result.samples["parameters"])
    for i in range(n):
        if i % 100 == 0:
            print(i)
        sample = result.samples["parameters"][i]
        std = result.samples["std"][i]
        means = experiment._model_transformation.apply_from_vector(x, sample)
        means_history.append(means)   
        likelihood_distribution = experiment._model._outputs_likelihood(means, jnp.ones_like(means) * std)
        log_likelihood = likelihood_distribution.log_prob(y.squeeze())
        likelihood = jnp.exp(log_likelihood)
        posterior_predictive += likelihood
        posterior_predictive_history.append(posterior_predictive / (i + 1))
        if i > 0:
            # posterior predictive
            tmp_posterior_predictive_before = posterior_predictive_history[-2]
            tmp_posterior_predictive_after = posterior_predictive_history[-1]
            kl_divergence_value = kl_divergence(
                tmp_posterior_predictive_after,
                tmp_posterior_predictive_before
            )
            kl_divergences.append(kl_divergence_value.mean().item())

            # posterior parameters - THIS REQUIRES FITTING FIRST - MAYBE KDE?
            #kl_divergences_parameters.append(kl_divergence(
            #    result.samples["parameters"][:i + 1],
            #    result.samples["parameters"][:i]
            #).item())
    return posterior_predictive_history, kl_divergences

# %%
posterior_predictive_history_n1, kl_divergences_n1 = kl_divergence_grid(128, experiment_n1, result_n1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200

# %%
posterior_predictive_history_n10, kl_divergences_n10 = kl_divergence_grid(128, experiment_n10, result_n10)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700

# %%
textsize=22

# %%
xx, yy = jnp.meshgrid(x.squeeze(), y.squeeze())
textsize=22
csfont = {'fontname':'Times New Roman'}

indices = [0, 15, 255, n-1]
cols = 4
rows = 1
plots = cols * rows
figure = plt.figure(figsize=(4 * cols, 4 * rows))
for row in range(rows):
    for col in range(cols):
        i = row * cols + col
        #posterior = int(((1.0 * i) / plots) * n)
        posterior = indices[i]
        ax = figure.add_subplot(rows, cols, i + 1)
        ax.set_xlim(-3.0, 3.0)
        ax.set_ylim(-3.0, 3.0)
        ax.set_title(f"{posterior + 1} samples", **csfont)
        
        if col == 0:
            ax.set_ylabel("y")
        if row == rows - 1:
            ax.set_xlabel("x")
        maximum, minimum = posterior_predictive_history[posterior].max(), posterior_predictive_history[posterior].min()
        values = 1.0 - (posterior_predictive_history[posterior] - minimum) / (maximum - minimum)
        values = posterior_predictive_history[posterior]
        ax.pcolormesh(xx, yy, 0.2**(values.T + 1e-6), cmap="Blues_r", shading="gouraud", rasterized=True)
        ax.scatter(experiment._dataset.data[:, 0], experiment._dataset.data[:, 1], c="black", s=1, rasterized=True)
        ax.yaxis.label.set_size(textsize)
        ax.xaxis.label.set_size(textsize)
        ax.tick_params(axis='both', which='major', labelsize=textsize - 2)
        ax.tick_params(axis='both', which='minor', labelsize=textsize - 2)
        ax.title.set_size(textsize)
        ax.set_aspect("equal")

#for mean in means_history:
#    ax.plot(x, mean, c="blue", alpha=0.01)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [8], in <cell line: 10>()
#      22 if row == rows - 1:
#      23     ax.set_xlabel("x")
# ---> 24 maximum, minimum = posterior_predictive_history[posterior].max(), posterior_predictive_history[posterior].min()
#      25 values = 1.0 - (posterior_predictive_history[posterior] - minimum) / (maximum - minimum)
#      26 values = posterior_predictive_history[posterior]
#
# IndexError: list index out of range
# WARNING:matplotlib.font_manager:findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
figure.savefig(os.path.join(global_settings.PATH_FIGURES, "posterior_predictive.pdf"), bbox_inches="tight", dpi=300, transparent=True)

# %%
# individual plots

xx, yy = jnp.meshgrid(x.squeeze(), y.squeeze())
csfont = {'fontname':'Times New Roman'}

indices = [0, 15, 255, n-1]
cols = 4
rows = 1
plots = cols * rows
for row in range(rows):
    for col in range(cols):
        figure = plt.figure(figsize=(4, 4))
        i = row * cols + col
        posterior = indices[i]
        ax = figure.add_subplot(1, 1, 1)
        ax.set_xlim(-3.0, 3.0)
        ax.set_ylim(-3.0, 3.0)
        
        maximum, minimum = posterior_predictive_history[posterior].max(), posterior_predictive_history[posterior].min()
        values = 1.0 - (posterior_predictive_history[posterior] - minimum) / (maximum - minimum)
        values = posterior_predictive_history[posterior]
        ax.pcolormesh(xx, yy, 0.2**(values.T + 1e-6), cmap="Blues_r", shading="gouraud", rasterized=True)
        ax.scatter(experiment._dataset.data[:, 0], experiment._dataset.data[:, 1], c="black", s=1, rasterized=True)
        ax.tick_params(axis='both', which='major', labelsize=textsize - 2)
        ax.tick_params(axis='both', which='minor', labelsize=textsize - 2)
        ax.set_aspect("equal")
        figure.savefig(os.path.join(global_settings.PATH_FIGURES, "posterior_predictive_{}.pdf".format(i)), bbox_inches="tight", dpi=300, transparent=True)

#for mean in means_history:
#    ax.plot(x, mean, c="blue", alpha=0.01)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [9], in <cell line: 11>()
#      17 ax.set_xlim(-3.0, 3.0)
#      18 ax.set_ylim(-3.0, 3.0)
# ---> 20 maximum, minimum = posterior_predictive_history[posterior].max(), posterior_predictive_history[posterior].min()
#      21 values = 1.0 - (posterior_predictive_history[posterior] - minimum) / (maximum - minimum)
#      22 values = posterior_predictive_history[posterior]
#
# IndexError: list index out of range

# %%
print(posterior_predictive_history[-1].shape)
# Out:
# (128, 128)

# %%
figure = plt.figure(figsize=(24, 4))
n2 = 100

ax1 = figure.add_subplot(1, 1, 1)
ax1.set_xlabel("samples")
ax1.set_ylabel(r"avg. KL-Div.", color="black")
ax1.yaxis.label.set_size(textsize)
ax1.xaxis.label.set_size(textsize)
ax1.tick_params(axis='both', which='major', labelsize=textsize - 2)
ax1.tick_params(axis='both', which='minor', labelsize=textsize - 2)

ax2 = ax1.twinx()
ax2.set_ylabel(r"log", color="tab:blue")
ax2.yaxis.label.set_size(textsize)
ax2.xaxis.label.set_size(textsize)
ax2.tick_params(axis='both', which='major', labelsize=textsize - 2)
ax2.tick_params(axis='both', which='minor', labelsize=textsize - 2)

# n1
kl_divergences = kl_divergences_n10
ax1.plot(jnp.arange(min(len(kl_divergences), n2)), jnp.array(kl_divergences)[:n2], color="gray", label="10 samples / chain")
ax2.plot(jnp.arange(min(len(kl_divergences), n2)), jnp.log(jnp.array(kl_divergences))[:n2], color="tab:blue", label="10 samples / chain")

# n10
kl_divergences = kl_divergences_n1
ax1.plot(jnp.arange(min(len(kl_divergences), n2)), jnp.array(kl_divergences)[:n2], color="black", label="1 sample / chain")
ax2.plot(jnp.arange(min(len(kl_divergences), n2)), jnp.log(jnp.array(kl_divergences))[:n2], color="tab:orange", label="1 sample / chain")

ax1.legend(loc="upper center")
ax2.legend()

# %%
figure.savefig(os.path.join(global_settings.PATH_FIGURES, "avg_kl_delta_overlay_samples_100.pdf"), bbox_inches="tight", dpi=300, transparent=True)

# %%
figure.savefig(os.path.join(global_settings.PATH_FIGURES, "avg_kl_delta_4chains.pdf"), bbox_inches="tight", dpi=300, transparent=True)

# %%
tmp = kl_divergence(
    posterior_predictive_history[1],
    posterior_predictive_history[0]
)

# %%
print(tmp.shape)
# Out:
# (128,)

# %%
figure = plt.figure(figsize=(4, 4))
ax = figure.add_subplot(1, 1, 1)
ax.plot(jnp.arange(tmp.shape[0]), tmp)

# %%
total_kl_divergences = []
for pp in posterior_predictive_history:
    total_kl_divergences.append(kl_divergence(
        posterior_predictive_history[-1],
        pp
    ).mean())

# %%
figure = plt.figure(figsize=(8, 4))
ax1 = figure.add_subplot(1, 1, 1)
ax1.plot(jnp.arange(len(total_kl_divergences)), (jnp.array(total_kl_divergences)), c="tab:blue")
ax1.set_xlabel("samples")
ax1.set_ylabel(r"avg KL-Div. (to final)", color="tab:blue")
ax1.yaxis.label.set_size(18)
ax1.xaxis.label.set_size(18)

ax2 = ax1.twinx()
ax2.plot(jnp.arange(len(total_kl_divergences)), jnp.log(jnp.array(total_kl_divergences)), color="tab:orange")
ax2.set_ylabel(r"log", color="tab:orange")
ax2.yaxis.label.set_size(18)
ax2.xaxis.label.set_size(18)

# %% [raw]
# figure.savefig(os.path.join(global_settings.PATH_FIGURES, "avg_kl_total.png"), bbox_inches="tight", dpi=96, transparent=True)
